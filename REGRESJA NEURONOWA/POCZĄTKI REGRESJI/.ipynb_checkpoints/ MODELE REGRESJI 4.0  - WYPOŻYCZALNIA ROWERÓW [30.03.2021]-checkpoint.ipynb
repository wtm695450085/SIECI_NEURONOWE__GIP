# %% [markdown]
# <span style="font-size: 250%;color:white;background:#1155cc"> MODEL
#
# <span style="font-size: 240%;color:#1155cc"> WYPOŻYCZALNIA ROWERÓW [weryfikacja jakości modelu]
#
# <span style="font-size: 110%;color:#1155cc">Celem jest wykonanie modelu, który pomógłby w przewidywaniu poziomu pobrań rowerów w wypożyczalni miejskiej.
#
# ![obraz.png](attachment:obraz.png)

# %%
import numpy as np
import statistics as stat
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy import stats
from numpy import median

# %%
df = pd.read_csv('/home/wojciech/Pulpit/11/hour.csv')

def green(text):
     print('\033[32m', text, '\033[0m', sep='') 

green(df.dtypes)
print()
print()
print(df.shape)

df.head(4)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
#
#
# (17379, 17)
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# ...

# %% [markdown]
# # Spis zmiennych:
#
# - <span style="font-size: 130%;color:#1155cc"> instant: </span>indeks rekordu
# - <span style="font-size: 130%;color:#1155cc">dteday:</span> data
# - <span style="font-size: 130%;color:#1155cc">season:</span> sezon (1: wiosenny, 2: lato, 3: jesień, 4: zima)
# - <span style="font-size: 130%;color:#1155cc">yr:</span> rok (0: 2011, 1: 2012)
# - <span style="font-size: 130%;color:#1155cc">mnth:</span> miesiąc (od 1 do 12)
# - <span style="font-size: 130%;color:#1155cc">hr .: </span>godzina (od 0 do 23)
# - <span style="font-size: 130%;color:#1155cc">holiday: </span>pogoda jest dniem świątecznym lub nie (pobrane z http://dchr.dc.gov/page/holiday-schedule)
# - <span style="font-size: 130%;color:#1155cc">weekday: </span>dzień tygodnia
# - <span style="font-size: 130%;color:#1155cc">workingday: </span>jeśli dzień nie jest ani weekendem, ani dniem wolnym od pracy wynosi 1, w przeciwnym razie wynosi 0.
# + <span style="font-size: 130%;color:#1155cc">weathersit:</span>
#     - 1: Bezchmurnie, Niewiele chmur, Częściowe zachmurzenie, Częściowe zachmurzenie
#     - 2: Mgła + Pochmurno, Mgła + Przerwane chmury, Mgła + Kilka chmur, Mgła
#     - 3: lekki śnieg, lekki deszcz + burza z piorunami + rozproszone chmury, lekki deszcz + rozproszone chmury
#     - 4: ulewny deszcz + lodowe palety + burza z piorunami + mgła, śnieg + mgła
# - <span style="font-size: 130%;color:#1155cc">temp: </span>Znormalizowana temperatura w stopniach Celsjusza. Wartości są podzielone na 41 (maks.)
# - <span style="font-size: 130%;color:#1155cc">atemp: </span>Znormalizowana temperatura odczuwania w stopniach Celsjusza. Wartości są podzielone na 50 (maks.)
# - <span style="font-size: 130%;color:#1155cc">hum: </span>znormalizowana wilgotność. Wartości są podzielone na 100 (maks.)
# - <span style="font-size: 130%;color:#1155cc">windspeed: </span>znormalizowana prędkość wiatru. Wartości są podzielone na 67 (maks.)
# - <span style="font-size: 130%;color:#9900ff">casual:</span> liczba przypadkowych użytkowników
# - <span style="font-size: 130%;color:#9900ff">registered:</span> liczba zarejestrowanych użytkowników
# - <span style="font-size: 130%;color:red">cnt: liczba wszystkich wypożyczonych rowerów, w tym zarówno zwykłych, jak i zarejestrowanych
#
#     ![obraz.png](attachment:obraz.png)

# %% [markdown]
# <span style="font-size: 150%;color:#1155cc"> Zmniejszenie populacji do dalszych obliczeń

# %%
df = df.sample(frac = 1.0, random_state=148)
df.shape
# Out:
# (17379, 17)

# %% [markdown]
# <span style="font-size: 150%;color:#1155cc"> Wycinam żelazną rezerwę testową
#
# Wycinam 1% procent ostatnich rekordów, które będa służyły do sprawdzenia zdolności prognostycznych. Dlatego ostatnich bo to jest szereg czasowy. Można wyciąc jakiś inny okres. ważne żeby ten okres nie brał udziału w żadnych obliczeniach.

# %%
R,C =df.shape
F = R*0.01
L = R - F
L
# Out:
# 17205.21

# %%
df5 = df[df.index>=L]
df = df[df.index<L]
print('Zbiór super testowy df5:',df5.shape)
print('df:                    ',df.shape)
# Out:
# Zbiór super testowy df5: (173, 17)
# df:                     (17206, 17)

# %% [markdown]
# Zapisuje żelazną próbkę na dysk.

# %%
df5.to_csv('/home/wojciech/Pulpit/7/df5test.csv')

# %% [markdown]
# <span style="font-size: 150%;color:#1155cc"> Sprawdzam czy są braki w danych.

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
a,b = df.shape     #<- ile mamy kolumn
b

print('NUMBER OF EMPTY RECORDS vs. FULL RECORDS')
print('----------------------------------------')
for i in range(1,b):
    i = df.columns[i]
    r = df[i].isnull().sum()
    h = df[i].count()
    pr = (r/h)*100
   
    if r > 0:
        print(i,"--------",r,"--------",h,"--------",pr)
# Out:
# NUMBER OF EMPTY RECORDS vs. FULL RECORDS
# ----------------------------------------

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Dane nie mają braków. Szukam czy nie ma błędów. Zmienne nie mają błędów.

# %%
df.agg(['min', 'max', 'mean', 'median'])
# Out:
#         instant      dteday    season        yr       mnth         hr  \
# min         1.0  2011-01-01  1.000000  0.000000   1.000000   0.000000
# max     17206.0  2012-12-24  4.000000  1.000000  12.000000  23.000000
# mean     8603.5         NaN  2.516738  0.497559   6.482855  11.543589
# median   8603.5         NaN  3.000000  0.000000   6.000000  12.000000
#
#          holiday   weekday  workingday  weathersit      temp     atemp  \
# min     0.000000  0.000000    0.000000    1.000000  0.020000  0.000000
# max     1.000000  6.000000    1.000000    4.000000  1.000000  1.000000
# mean    0.027723  3.004359    0.683657    1.421132  0.499453  0.478121
# median  0.000000  3.000000    1.000000    1.000000  0.500000  0.484800
#
#              hum  windspeed      casual  registered         cnt
# min     0.000000   0.000000    0.000000    0.000000    1.000000
# max     1.000000   0.850700  367.000000  886.000000  977.000000
# mean    0.626817   0.189731   35.898989  154.734395  190.633384
# ...

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Zmiana formatu zmiennych niezależnych</span>
#
# Które z tych funkcji są kategoryczne?
#
# Stawiam dwa warunki:
#
# 1. funkcja jest kategoryczna bo ma format 'object'
# 2. funkcja jest kategoryczna bo ma do 24 unikalnych wartości

# %%
a,b = df.shape     #<- ile mamy kolumn
b

print('ONLY DISCRETE FUNCTION')
print('----------------------')
for i in range(1,b):
    i = df.columns[i]
    f = df[i].dtypes
    h = df[i].nunique()
    
    if f == np.object or h<=24:
        print(i,"---",f,"---",h)
# Out:
# ONLY DISCRETE FUNCTION
# ----------------------
# dteday --- object --- 724
# season --- int64 --- 4
# yr --- int64 --- 2
# mnth --- int64 --- 12
# hr --- int64 --- 24
# holiday --- int64 --- 2
# weekday --- int64 --- 7
# workingday --- int64 --- 2
# weathersit --- int64 --- 4

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Zmienne dyskretne mają format 'int64' a powinny mieć 'object'.

# %%
df.loc[:, 'season':'weathersit'] =  df.loc[:, 'season':'weathersit'].astype('category')

# %%
df.dtypes
# Out:
# instant          int64
# dteday          object
# season        category
# yr            category
# mnth          category
# hr            category
# holiday       category
# weekday       category
# workingday    category
# weathersit    category
# temp           float64
# atemp          float64
# hum            float64
# windspeed      float64
# casual           int64
# registered       int64
# cnt              int64
# dtype: object

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Redukcja ilości zmiennych

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Niektóre kolumny należy usunąć, ponieważ mają wysoki poziom korelacji zmiennych niezależnych (multicollinearity)

# %%
import seaborn as sns

CORR = df.corr()

kot = CORR[CORR>=.7]
plt.figure(figsize=(8,5))
sns.heatmap(kot, cmap="Greens")

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Na wykresie widać wyraźnie, że zmienne atempt i tempt są zbyt mocno skorelowane. Należy jedną z tych skorelowanych zmiennych wyeliminować.Ponieważ wynik 'cnt' i zmienne 'temp' i 'atemp' mają format ciągły, można zastosować eliminację przez porównanie poziomu korelacji Persona.

# %%
import matplotlib.pyplot as plt

corr = df.corr().sort_values('cnt')
plt.figure(figsize=(6,3))
corr['cnt'].plot(kind='barh', color='red')
plt.title('Korelacja ze zmienną wynikową cnt', fontsize=20)
plt.xlabel('Poziom korelacji')
plt.ylabel('Zmienne nezależne ciągłe')
# Out:
# Text(0, 0.5, 'Zmienne nezależne ciągłe')

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> 'temp', 'atemp', 'instant'</span>
#
# <span style="font-size: 110%;color:#1155cc">Zmienna 'temp' jest bardziej skorelowana niż 'atemp'. Eliminujemy też zmienną 'instant' ponieważ nie ma żadenj wartości poznawczej dla modelu.

# %%
df = df.drop(['instant','dteday'], axis=1)

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> 'casual', 'registered'</span>
#
# <span style="font-size: 110%;color:#1155cc">Zemienne: 'casual', 'registered' na tym etapie nie powinny być brane pod uwage w budowie modelu ponieważ są one zmiennymi wynikowymi.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> 'windspeed'</span>
#
# <span style="font-size: 110%;color:#1155cc"> Zmienna: 'windspeed' ma słabą korelację. Siła wiatru przy jeździe rowerem ma wielkie znaczenie. Podejrzewam, że zmienna ta ma znaczenie przy decyzji o wyporzyczeniu roweru ale decyzja ta jest opóźniona o tzn. shift.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Analiza przesunięcia czasowego dla zmiennej 'windspeed'

# %%
def cross_corr(x, y, lag=0):
    return x.corr(y.shift(lag))

def shift_Factor(x,y,R):
    x_corr = [cross_corr(x, y, lag=i) for i in range(R)]
    
    # R factor is the number of the shifts who should be checked by the function
    Kot = pd.DataFrame(list(x_corr)).reset_index()
    Kot.rename(columns={0:'Corr', 'index':'Shift_num'}, inplace=True)
    
    # We find optimal correlation shift
    Kot['abs'] = Kot['Corr'].abs()
    SF = Kot.loc[Kot['abs']==Kot['abs'].max(), 'Shift_num']
    p1 = SF.to_frame()
    SF = p1.Shift_num.max()
    
    return SF

# %%
x = df.windspeed     # independent variable
y = df['cnt']    # dependent variable
R = 20           # number of shifts who will be checked

# %%
SKO = shift_Factor(x,y,R)
print('Optimal shift for RH: ',SKO)
print()
b = cross_corr(x, y, lag=SKO)
a = cross_corr(df['temp'], df['cnt'], lag=SKO)
print('Przed shift: %.3f' %a)
print('Po shift:    %.3f' %b)
# Out:
# Optimal shift for RH:  0
#
# Przed shift: 0.401
# Po shift:    0.096

# %% [markdown]
#  <span style="font-size: 110%;color:#1155cc"> Teraz dostoswuję bazę do shift. Okazuje się, że klienci rezygnują z wypożyczenie rowerów dopiero po 13 godzinach od nasilenia wiatru ("windspeed"). Zjawisko należałoby dokładnie zbadać. prawdopodobnie klienci jadąc do pracy lub wracając z pracy na rowerze musieli zmagać się z wiatrem i tego samego dnia lub następnego dnia zrezygnowali z wypożyczenia roweru. Ujemna korelacja jest niewielka lecz znacząca -20%.
#
#  <span style="font-size: 110%;color:#1155cc">Tworzę funkcja tworzenia przesunięcia danych.

# %%
def df_shif(df, target=None, lag=0):
    if not lag and not target:
        return df       
    new = {}
    for h in df.columns:
        if h == target:
            new[h] = df[target]
        else:
            new[h] = df[h].shift(periods=lag)
    return  pd.DataFrame(data=new)

# %%
df2 = df[['temp','hum','windspeed','season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit', 'cnt']]

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Tworzę zdublowaną zmienną 'windspeed_shift' z uwzględnieniem przesunięcia 13 godzinnego.

# %%
df2['windspeed_shift'] = df2['windspeed']
# Out:
# /home/wojciech/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3 = df_shif(df2, 'windspeed_shift', lag=13)
df3.head(7)
## Kasuje dziurę czasową
df3 = df3.dropna(how ='any')
df3.tail(15)
# Out:
#        temp   hum  windspeed season yr mnth  hr holiday weekday workingday  \
# 15079  0.36  0.27     0.1343      1  1    2  15       0       1          1
# 16404  0.32  0.49     0.1642      1  1    2   1       0       6          0
# 4835   0.28  0.41     0.3582      4  1   11   3       0       6          0
# 9375   0.64  0.73     0.2537      2  1    5  20       0       2          1
# 12961  0.82  0.34     0.1940      3  1    8  17       0       4          1
# 10297  0.36  0.57     0.1940      4  1   11  16       0       4          1
# 15814  0.40  0.40     0.6119      1  0    2  18       0       1          1
# 8484   0.74  0.70     0.2985      2  1    5  10       0       2          1
# 6601   0.60  0.88     0.1343      4  0    9   7       0       4          1
# 1248   0.84  0.47     0.0896      3  1    7  16       0       4          1
# 7074   0.48  0.23     0.4179      1  1    3  16       0       5          1
# ...

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Kasujemy zmienną 'windspeed'.

# %%
df3 = df3.drop(['windspeed'], axis=1)

# %%
import matplotlib.pyplot as plt

corr = df3.corr().sort_values('cnt')
plt.figure(figsize=(6,3))
corr['cnt'].plot(kind='barh', color='red')
plt.title('Korelacja ze zmienną wynikową cnt', fontsize=20)
plt.xlabel('Poziom korelacji')
plt.ylabel('Zmienne nezależne ciągłe')
# Out:
# Text(0, 0.5, 'Zmienne nezależne ciągłe')

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Pozostały nam cztery zmienne opisujące. To są zmienne ciągłe. Niestety wiele zmiennych jest dyskretnych i dlatego nie nadają się do modelu regresji liniowej. Te zmienne należy włączyć do modelu regresji poprzez tzw. metodę kodowania na gorąco.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Przegląd wartości unikalnych dla zmiennych dyskretnych

# %%
print(df3['season'].unique())
# Out:
# [1, 4, 2, 3]
# Categories (4, int64): [1, 4, 2, 3]

# %%
a,b = df3.shape     #<- ile mamy kolumn
b

import numpy as np

for i in range(1,b):
    i = df3.columns[i]
    h = df3[i].nunique()
    f = df3[i].dtypes
          
    print(f,'---nunique->',h,'---name->', i)
# Out:
# float64 ---nunique-> 89 ---name-> hum
# category ---nunique-> 4 ---name-> season
# category ---nunique-> 2 ---name-> yr
# category ---nunique-> 12 ---name-> mnth
# category ---nunique-> 24 ---name-> hr
# category ---nunique-> 2 ---name-> holiday
# category ---nunique-> 7 ---name-> weekday
# category ---nunique-> 2 ---name-> workingday
# category ---nunique-> 4 ---name-> weathersit
# float64 ---nunique-> 869 ---name-> cnt
# float64 ---nunique-> 30 ---name-> windspeed_shift

# %%
a,b = df3.shape     #<- ile mamy kolumn
b

print('ONLY DISCRETE FUNCTION')
print('----------------------')
for i in range(1,b):
    i = df2.columns[i]
    f = df2[i].dtypes
    h = df2[i].nunique()
    
    if f == np.object or h<=10:
        print(i,"---",f,"---",h)
# Out:
# ONLY DISCRETE FUNCTION
# ----------------------
# season --- category --- 4
# yr --- category --- 2
# holiday --- category --- 2
# weekday --- category --- 7
# workingday --- category --- 2
# weathersit --- category --- 4

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Wypisuje zmienne, które są dyskretne i które należy kodować na gorąco.

# %%
discrete_var = ['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

# %%
df3.columns
# Out:
# Index(['temp', 'hum', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'cnt', 'windspeed_shift'],
#       dtype='object')

# %%
data_dummy = df3    ## d3 to ten zbiór, na którym operujemy

def dummify_dataset(df, col):
    dummy_column = pd.get_dummies(df[col], prefix = col, drop_first = True)
    PKP = pd.concat([df,dummy_column],axis = 1)
    PKP = PKP.drop([col], axis=1)
    return PKP


discrete_var = ['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

for i in range(0,8):     #<<< Tu trzeba wpisać ile jest zmiennych dyskretnych
    data_dummy = dummify_dataset(data_dummy,discrete_var[i])
    
df4 = data_dummy 
df4.sample(3)

# %%
# Out:
#        temp   hum    cnt  windspeed_shift  season_2  season_3  season_4  yr_1  \
# 8041   0.76  0.52  293.0           0.2239         0         1         0     1
# 9854   0.76  0.66   42.0           0.1940         0         1         0     0
# 10589  0.76  0.66  686.0           0.0896         0         1         0     1
#
#        mnth_2  mnth_3  ...  weekday_1  weekday_2  weekday_3  weekday_4  \
# 8041        0       0  ...          0          0          1          0
# 9854        0       0  ...          0          0          0          0
# 10589       0       0  ...          0          0          1          0
#
#        weekday_5  weekday_6  workingday_1  weathersit_2  weathersit_3  \
# 8041           0          0             0             0             0
# 9854           0          1             0             0             0
# 10589          0          0             1             0             0
#
#        weathersit_4
# 8041              0
# 9854              0
# ...

# %%
df4.columns
# Out:
# Index(['temp', 'hum', 'cnt', 'windspeed_shift', 'season_2', 'season_3',
#        'season_4', 'yr_1', 'mnth_2', 'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6',
#        'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11', 'mnth_12', 'hr_1',
#        'hr_2', 'hr_3', 'hr_4', 'hr_5', 'hr_6', 'hr_7', 'hr_8', 'hr_9', 'hr_10',
#        'hr_11', 'hr_12', 'hr_13', 'hr_14', 'hr_15', 'hr_16', 'hr_17', 'hr_18',
#        'hr_19', 'hr_20', 'hr_21', 'hr_22', 'hr_23', 'holiday_1', 'weekday_1',
#        'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6',
#        'workingday_1', 'weathersit_2', 'weathersit_3', 'weathersit_4'],
#       dtype='object')

# %% [markdown]
#  <span style="font-size: 110%;color:#1155cc"> Podział zbioru na testowy i treningowy.

# %%
from sklearn.model_selection import train_test_split 

y = df4['cnt']
X = df4.drop('cnt', axis=1)

Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, test_size=0.25, random_state = 148)

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Uruchamiam paczkę modeli regresji
#
# <span style="font-size: 110%;color:#1155cc">Celem jest wybranie najlepszego modelu.

# %%
from sklearn.linear_model import LinearRegression, Ridge, HuberRegressor, ElasticNetCV
from sklearn.ensemble import BaggingRegressor, ExtraTreesRegressor, GradientBoostingRegressor, RandomForestRegressor,AdaBoostRegressor
from sklearn.dummy import DummyRegressor
from sklearn.neighbors import KNeighborsRegressor


from sklearn import model_selection
from sklearn.metrics import mean_squared_log_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR


import warnings   
warnings.filterwarnings("ignore")

modele = [KNeighborsRegressor(),
          DecisionTreeRegressor(),
          BaggingRegressor(),
          GradientBoostingRegressor(),
          LinearRegression(),
          AdaBoostRegressor(),
          Ridge(),
          HuberRegressor(),
          ElasticNetCV(), 
          ExtraTreesRegressor(),
          RandomForestRegressor(),
          SVR()]  


nazwy = ['KNeighbors_Regressor',
          'Decision_Tree_Regressor',
          'Bagging_Regressor',
          'Gradient_Boosting_Regressor',
          'Linear_Regression',
          'AdaBoost_Regressor',
          'Ridge',
          'Huber_Regressor',
          'Elastic_Net_CV',
          'ExtraTreesRegressor',
          'Random_Forest_Regressor',
          'Support_Vector_Regression'
          ]

# %%
def model_val(t):
    
    global mean_dev,r2
    
    kfold = model_selection.KFold(n_splits=9, random_state=148)
    mean_dev = model_selection.cross_val_score(t, Xtrain, ytrain, cv=kfold, scoring='neg_mean_absolute_error')
    mean_dev = np.round(mean_dev, decimals=1)
    r2 = model_selection.cross_val_score(t, Xtrain, ytrain, cv=kfold, scoring='r2')
    r2 = np.round(r2, decimals=2)
    
    return mean_dev,r2

# %%
def green(text):
     print('\033[32m', text, '\033[0m', sep='')
        
def red(text):
     print('\033[31m', text, '\033[0m', sep='')

# %% [markdown]
# Miejsce zapisania modeli na dysk:

# %%
address1 ='/home/wojciech/Pulpit/7/model1-{0}.pkl'  #<=  modele na ustawieniach fabrycznych

# %%
for n,p in zip(nazwy,modele):      
    
    import matplotlib.pyplot as plt
    import time   
    import joblib
    
    start_time = time.time()
    
    results = model_val(p)
    print()
    red(n)
    print("-------------------------------cross_val, KFold = 9 ------")
    print('R2: ', r2)
    print('Mean_dev: ', mean_dev)
    
    # wykres
    
    plt.rc("font",size=14)
    clf = p
    clf.fit(Xtrain,ytrain)
    ypred = clf.predict(Xtest)
    
    ax = sns.regplot(ytest,ypred,color='grey')
    plt.title(n,color='r') 
    plt.ylabel('count', fontsize=12) 
    plt.xlabel('count', fontsize=12) 
    plt.show()
    
     ## --------------------------------------
    filename1 =address1.format(n)           #<= zapisujemy model na dysku
    _ = joblib.dump(p, filename1, compress=9)   #<= zapisujemy model na dysku
    
    ## --------------------------------------
      
    # pomiar czasu
    n = (time.time() - start_time)
    n = np.round(n)
    print('time: %s seconds' % n)    
    print()
# Out:
# KNeighbors_Regressor
# -------------------------------cross_val, KFold = 9 ------
# R2:  [0.69 0.7  0.69 0.67 0.69 0.68 0.68 0.69 0.68]
# Mean_dev:  [-70.4 -64.1 -64.3 -69.1 -69.  -66.7 -65.5 -64.7 -65. ]
# time: 28.0 seconds
#
#
# Decision_Tree_Regressor
# -------------------------------cross_val, KFold = 9 ------
# R2:  [0.83 0.84 0.84 0.84 0.82 0.82 0.82 0.85 0.83]
# Mean_dev:  [-46.8 -44.5 -44.4 -44.6 -47.4 -46.8 -46.9 -42.8 -46.1]
# time: 4.0 seconds
#
#
# Bagging_Regressor
# -------------------------------cross_val, KFold = 9 ------
# R2:  [0.9  0.9  0.9  0.91 0.9  0.89 0.9  0.89 0.89]
# Mean_dev:  [-38.8 -36.7 -36.3 -35.9 -36.8 -37.9 -35.3 -36.4 -36.8]
# time: 22.0 seconds
#
#
# Gradient_Boosting_Regressor
# -------------------------------cross_val, KFold = 9 ------
# R2:  [0.8  0.8  0.81 0.81 0.8  0.8  0.81 0.8  0.8 ]
# Mean_dev:  [-61.1 -60.6 -55.9 -59.3 -61.6 -58.9 -56.3 -56.9 -57.2]
# time: 35.0 seconds
#
#
# Linear_Regression
# ...

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Kodowanie na gorąco powoduje skokowy wzrost ilości zmiennych. Niektóre, nowe zmienne mogą okazać się niepotrzebne lub nawet szkodliwie dla modelu. Watro więc zrobić analizę zmiennych. Jest wiele sposobów selekcji zmiennych. ja wybrałem: 'Step Forward Selection'.
#
#
# <span style="font-size: 180%;color:#1155cc"> Elininacja nowych zmiennych niezależnych - Step Forward Selection
#
# <span style="font-size: 110%;color:#1155cc">Selekcja 'Step Forward' to metoda iteracyjna, w której zaczynamy od braku funkcji w modelu. W każdej iteracji dodajemy zmienną, która ulepsza model, dopóki dodanie kolejnej nowej zmiennej nie poprawi już wydajności modelu.

# %% [raw]
# k_features = 16

# %% [raw]
# from sklearn.linear_model import LinearRegression
# from mlxtend.feature_selection import SequentialFeatureSelector as sfs
#
# LR =  DecisionTreeRegressor()
#
# sfs1 = sfs(LR,k_features = k_features, forward=True, floating=False, scoring='r2',verbose=2,cv=5)
# sfs1 = sfs1.fit(Xtrain,ytrain)

# %% [raw]
# feat_cols =list(sfs1.k_feature_idx_)
# print(feat_cols)

# %% [raw]
# X.columns

# %% [raw]
# new_cols = X.columns

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Tworzę zbiór danych ze zredukowanymi kolumnami.

# %% [raw]
# df5 = df4[new_cols]
# df5['cnt']=df4['cnt']
# df5.head(3)

# %% [raw]
# from sklearn.model_selection import train_test_split
#
# y5 = df5['cnt']
# X5 = df5.drop('cnt', axis=1)
#
# X5train, X5test, y5train, y5test = train_test_split(X5,y5, test_size=0.25, random_state = 148)

# %% [raw]
# for n,p in zip(nazwy,modele):
#
#     import matplotlib.pyplot as plt
#     import time
#
#     start_time = time.time()
#
#     results = model_val(p)
#     print()
#     red(n)
#     print("-------------------------------cross_val, KFold = 9 ------")
#     print('R2: ', r2)
#     print('Mean_dev: ', mean_dev)
#
#     # wykres
#
#     plt.rc("font",size=14)
#     clf = p
#     clf.fit(X5train,y5train)
#     ypred = clf.predict(X5test)
#
#     ax = sns.regplot(ytest,ypred,color='grey')
#     plt.title(n,color='r')
#     plt.ylabel('count', fontsize=12)
#     plt.xlabel('count', fontsize=12)
#     plt.show()
#
#     # pomiar czasu
#     n = (time.time() - start_time)
#     n = np.round(n)
#     print('time: %s seconds' % n)
#     print()

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Eliminacja zmiennych nie poprawiła właściwości modeli. Wracam do zbioru pełną ilością zmiennych dommy: df4.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Tuning modeli
#
# <span style="font-size: 110%;color:#1155cc">Analiza cross validation bez szczególnych ustawień hiperparametrów, na pełnym zestawie zmiennych niezależnych pokazała, że istnieją trzy najlepsze modele regresji:
#
#         - Bagging Regressor
#         - Random Forest Regressor
#         - Extra Trees Regressor
# <span style="font-size: 110%;color:#1155cc">Teraz należy udoskonalić te modele poprzez dobór hiperparametrów.

# %% [markdown]
#  <span style="font-size: 150%;color:white;background:#1155cc"> Optymalizacja 'Bagging Regressor'

# %%
from sklearn.dummy import DummyRegressor
import time   
    
start_time = time.time()

# DummyRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(gamma='scale')

parameters={"base_estimator": [DecisionTreeRegressor(),KNeighborsRegressor()],
                          "max_samples": [0.5, 1.0],
                          "max_features": [0.5, 1.0],
                          "bootstrap": [True, False],
                          "bootstrap_features": [True, False]}

BaggingRegressor_OP = GridSearchCV(BaggingRegressor(), parameters,scoring = 'r2')
BaggingRegressor_OP.fit(Xtrain,ytrain)

print('BaggingRegressor:',BaggingRegressor_OP.best_score_)
print(BaggingRegressor_OP.best_params_)
print(BaggingRegressor_OP.best_estimator_)

# wykres
    
plt.rc("font",size=14)
BaggingRegressor_OP.fit(Xtrain,ytrain)
ypred = BaggingRegressor_OP.predict(Xtest)

ax = sns.regplot(ytest,ypred,color='#45818e')
plt.title('Bagging Regressor:',color='#134f5c') 
plt.ylabel('count', fontsize=12) 
plt.xlabel('count', fontsize=12) 
plt.show()

## ----------------zapisujemy model na dysku----------------------

filename ='/home/wojciech/Pulpit/7/model2-BaggingRegressor_OP.pkl'  #<=  ścieżka i nazwa modelu
_ = joblib.dump(BaggingRegressor_OP, filename, compress=9)   #<= zapisujemy model na dysku
    
## ---------------------------------------------------------------

# pomiar czasu
n = (time.time() - start_time)
n = np.round(n)
print('time: %s seconds' % n)
# Out:
# BaggingRegressor: 0.8968797290656731
# {'base_estimator': DecisionTreeRegressor(), 'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# BaggingRegressor(base_estimator=DecisionTreeRegressor())
# time: 2479.0 seconds

# %% [markdown]
# <span style="font-size: 150%;color:white;background:#1155cc"> Optymalizacja 'Random Forest Regressor'

# %%
import time   
    
start_time = time.time()

parameters={"n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],}

RandomForestRegressor_OP = GridSearchCV(RandomForestRegressor(), parameters,scoring = 'r2')
RandomForestRegressor_OP.fit(Xtrain,ytrain)

print('Random Forest Regressor:',RandomForestRegressor_OP.best_score_)
print(RandomForestRegressor_OP.best_params_)
print(RandomForestRegressor_OP.best_estimator_)

    # wykres
    
plt.rc("font",size=14)
RandomForestRegressor_OP.fit(Xtrain,ytrain)
ypred = RandomForestRegressor_OP.predict(Xtest)

ax = sns.regplot(ytest,ypred,color='#45818e')
plt.title('Random Forest Regressor',color='#134f5c') 
plt.ylabel('count', fontsize=12) 
plt.xlabel('count', fontsize=12) 
plt.show()

## ----------------zapisujemy model na dysku----------------------

filename ='/home/wojciech/Pulpit/7/model2-RandomForestRegressor_OP.pkl'  #<=  ścieżka i nazwa modelu
_ = joblib.dump(RandomForestRegressor_OP, filename, compress=9)   #<= zapisujemy model na dysku
    
## ---------------------------------------------------------------

# pomiar czasu
n = (time.time() - start_time)
n = np.round(n)
print('time: %s seconds' % n)
# Out:
# Random Forest Regressor: 0.9036379377512599
# {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 4, 'n_estimators': 30}
# RandomForestRegressor(min_samples_split=4, n_estimators=30)
# time: 513.0 seconds

# %% [markdown]
# <span style="font-size: 150%;color:white;background:#1155cc"> Optymalizacja 'Extra Trees Regressor'

# %%
from sklearn.ensemble import ExtraTreesRegressor

parameters={'n_estimators': [50,100,500],
            'min_samples_leaf': [1,5,10],
            'min_samples_split': [5,10,20]}

ExtraTreesRegressor_OP = GridSearchCV(ExtraTreesRegressor(), parameters,scoring = 'r2')
ExtraTreesRegressor_OP.fit(Xtrain,ytrain)

print('Extra Trees Regressor:',ExtraTreesRegressor_OP.best_score_)
print(ExtraTreesRegressor_OP.best_params_)
print(ExtraTreesRegressor_OP.best_estimator_)

    # wykres
    
plt.rc("font",size=14)
ExtraTreesRegressor_OP.fit(Xtrain,ytrain)
ypred = ExtraTreesRegressor_OP.predict(Xtest)

ax = sns.regplot(ytest,ypred,color='#45818e')
plt.title('Extra Trees Regressor',color='#134f5c') 
plt.ylabel('count', fontsize=12) 
plt.xlabel('count', fontsize=12) 
plt.show()

## ----------------zapisujemy model na dysku----------------------

filename ='/home/wojciech/Pulpit/7/model2-ExtraTreesRegressor_OP.pkl'  #<=  ścieżka i nazwa modelu
_ = joblib.dump(ExtraTreesRegressor_OP, filename, compress=9)   #<= zapisujemy model na dysku
    
## ---------------------------------------------------------------

# pomiar czasu
n = (time.time() - start_time)
n = np.round(n)
print('time: %s seconds' % n)
# Out:
# Extra Trees Regressor: 0.9234174134189826
# {'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# ExtraTreesRegressor(min_samples_split=10, n_estimators=500)
# time: 4409.0 seconds

# %% [markdown]
#  <span style="font-size: 180%;color:#1155cc"> MODELE WYNIKOWE
#
# <span style="font-size: 110%;color:#1155cc">Wydzielamy jakiś losowy okres z próbki danych i sprawdzamy jak działają modele. Wydzielilismy rok: 0, sezon:2 ('lato').

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> PRZYGOTOWANIE DANYCH DO UŻYCIA MODELI

# %%
dfk = pd.read_csv('/home/wojciech/Pulpit/11/hour.csv')
# &(dfk.yr==0)&(dfk.weekday==1)&(dfk.hr>=1)&(dfk.hr<=5)
dfk = dfk.loc[(dfk.season==2)]
print(dfk.shape)
dfk.tail(3)
# Out:
# (4409, 17)
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 12760    12761  2012-06-20       2   1     6  21        0        3
# 12761    12762  2012-06-20       2   1     6  22        0        3
# 12762    12763  2012-06-20       2   1     6  23        0        3
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 12760           1           1  0.84  0.7576  0.44     0.0896      42
# 12761           1           1  0.82  0.7576  0.46     0.1045      31
# 12762           1           1  0.78  0.7424  0.59     0.1045      21
#
#        registered  cnt
# 12760         302  344
# 12761         226  257
# 12762         102  123

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Tworzymy shift dla 'windspeed'.

# %%
dfk.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
dfk2 = dfk[['dteday','temp','hum','windspeed','season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit', 'cnt']]

# %% [markdown]
#  <span style="font-size: 110%;color:#1155cc"> Tworzymy 'windspeed_shift' z uwzględnieniem przesunięcia 13 godzinnego.

# %%
dfk2['windspeed_shift'] = dfk2['windspeed']

# %%
dfk3 = df_shif(dfk2, 'windspeed_shift', lag=13)
dfk3.head(7)
## Kasuje dziurę czasową
dfk3 = dfk3.dropna(how ='any')
dfk3.head(3)
# Out:
#           dteday  temp   hum  windspeed  season   yr  mnth   hr  holiday  \
# 1820  2011-03-21  0.34  0.66     0.3881     2.0  0.0   3.0  0.0      0.0
# 1821  2011-03-21  0.34  0.71     0.3881     2.0  0.0   3.0  1.0      0.0
# 1822  2011-03-21  0.34  0.71     0.3284     2.0  0.0   3.0  2.0      0.0
#
#       weekday  workingday  weathersit   cnt  windspeed_shift
# 1820      1.0         1.0         3.0  13.0           0.2239
# 1821      1.0         1.0         2.0   7.0           0.2239
# 1822      1.0         1.0         2.0   6.0           0.2836

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Tworzymy kodowanie na gorąco.

# %%
data_dummy = dfk3

def dummify_dataset(df, col):
    dummy_column = pd.get_dummies(df[col], prefix = col, drop_first = True)
    PKP = pd.concat([df,dummy_column],axis = 1)
    PKP = PKP.drop([col], axis=1)
    return PKP


discrete_var = ['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

for i in range(0,8):
    data_dummy = dummify_dataset(data_dummy,discrete_var[i])

# %%
dfk4 = data_dummy
dfk4.head(3)
# Out:
#           dteday  temp   hum  windspeed   cnt  windspeed_shift  yr_1.0  \
# 1820  2011-03-21  0.34  0.66     0.3881  13.0           0.2239       0
# 1821  2011-03-21  0.34  0.71     0.3881   7.0           0.2239       0
# 1822  2011-03-21  0.34  0.71     0.3284   6.0           0.2836       0
#
#       mnth_4.0  mnth_5.0  mnth_6.0  ...  holiday_1.0  weekday_1.0  \
# 1820         0         0         0  ...            0            1
# 1821         0         0         0  ...            0            1
# 1822         0         0         0  ...            0            1
#
#       weekday_2.0  weekday_3.0  weekday_4.0  weekday_5.0  weekday_6.0  \
# 1820            0            0            0            0            0
# 1821            0            0            0            0            0
# 1822            0            0            0            0            0
#
#       workingday_1.0  weathersit_2.0  weathersit_3.0
# 1820               1               0               1
# ...

# %%
dfk4.columns
# Out:
# Index(['dteday', 'temp', 'hum', 'windspeed', 'cnt', 'windspeed_shift',
#        'yr_1.0', 'mnth_4.0', 'mnth_5.0', 'mnth_6.0', 'hr_1.0', 'hr_2.0',
#        'hr_3.0', 'hr_4.0', 'hr_5.0', 'hr_6.0', 'hr_7.0', 'hr_8.0', 'hr_9.0',
#        'hr_10.0', 'hr_11.0', 'hr_12.0', 'hr_13.0', 'hr_14.0', 'hr_15.0',
#        'hr_16.0', 'hr_17.0', 'hr_18.0', 'hr_19.0', 'hr_20.0', 'hr_21.0',
#        'hr_22.0', 'hr_23.0', 'holiday_1.0', 'weekday_1.0', 'weekday_2.0',
#        'weekday_3.0', 'weekday_4.0', 'weekday_5.0', 'weekday_6.0',
#        'workingday_1.0', 'weathersit_2.0', 'weathersit_3.0'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Usuwamy zmienną 'dteday'

# %%
dfk5= dfk4.drop('dteday', axis=1)

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Dzielimy zbiór zmienne niezależne i zmieną zależną.

# %%
y = dfk5['cnt']
X = dfk5.drop('cnt', axis=1)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
from sklearn.ensemble import BaggingRegressor, ExtraTreesRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score


Bagging_Reg = BaggingRegressor(base_estimator=DecisionTreeRegressor())
Bagging_Reg = Bagging_Reg.fit(X,y)
dfk5['Bagging_Reg'] = Bagging_Reg.predict(X)

y_pred = Bagging_Reg.predict(X_test)
print('Bagging_Reg r2:      %.2f' % r2_score(y_test, y_pred))


ExtraTrees_Reg = ExtraTreesRegressor(min_samples_split=5, n_estimators=500)
ExtraTrees_Reg = ExtraTrees_Reg.fit(X,y)
dfk5['ExtraTrees_Reg'] = ExtraTrees_Reg.predict(X)
dfk5['ExtraTrees_Reg'] = np.round(dfk5['ExtraTrees_Reg'], decimals=1)
y_pred = ExtraTrees_Reg.predict(X_test)
print('ExtraTrees_Reg r2:   %.2f' % r2_score(y_test, y_pred))


RandomForest_Reg = RandomForestRegressor(n_estimators=30)
RandomForest_Reg = RandomForest_Reg.fit(X,y)
dfk5['RandomForest_Reg'] = RandomForest_Reg.predict(X)
dfk5['RandomForest_Reg'] = np.round(dfk5['RandomForest_Reg'], decimals=1)
y_pred = RandomForest_Reg.predict(X_test)
print('RandomForest_Reg r2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Bagging_Reg r2:      0.97
# ExtraTrees_Reg r2:   0.99
# RandomForest_Reg r2: 0.98

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Dodajemy zmienną 'dteday'

# %%
dfk5['dteday'] = dfk4['dteday']

dfk5[['dteday','Bagging_Reg','ExtraTrees_Reg','RandomForest_Reg','cnt']].sample(10)
# Out:
#            dteday  Bagging_Reg  ExtraTrees_Reg  RandomForest_Reg    cnt
# 11981  2012-05-18        301.0           266.2             274.1  258.0
# 12176  2012-05-27        161.4           175.1             189.4  137.0
# 3456   2011-05-28        205.6           184.7             219.1  177.0
# 10640  2012-03-23        242.3           263.0             246.4  271.0
# 12144  2012-05-25        536.6           553.7             516.2  584.0
# 11580  2012-05-02          3.7             4.0               4.2    4.0
# 3483   2011-05-29        358.7           383.2             362.3  402.0
# 2308   2011-04-10        214.5           191.0             185.5  230.0
# 10865  2012-04-02        601.7           595.3             595.3  589.0
# 11864  2012-05-14         86.6            63.1              76.5   35.0

# %% [markdown]
# <span style="font-size: 150%;color:#1155cc">Tworzę komitet modeli w proporcji:
#
# <div class="alert-info">
#
#      60% ExtraTrees_Reg
#      20% Bagging_Reg
#      20% RandomForest_Reg
# </div>

# %%
dfk5['KM'] = (0.6*dfk5['ExtraTrees_Reg'])+(0.2*dfk5['RandomForest_Reg'])+(0.2*dfk5['Bagging_Reg'])

# %% [markdown]
# <span style="font-size: 150%;color:#1155cc">Graficzny przebieg procesu

# %%
dfk5.reset_index
dfk5.set_index('dteday', inplace=True)
dfk5[['KM','cnt']].head(160).plot(figsize=(24,5))

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Test prgonozowania modeli na nieprzetrenowanej próbie 'sezon 4' (zima)
#
# <span style="font-size: 110%;color:#1155cc"> Teraz sprawdzamy jak modele zachowaja się na danych których nie znają. Moedel zostały przetrenowane na danych z lata. Teraz sprawdzimy te modele na danych z sezonu zimowego.

# %%
dk = pd.read_csv('/home/wojciech/Pulpit/11/hour.csv')
# &(dfk.yr==0)&(dfk.weekday==1)&(dfk.hr>=1)&(dfk.hr<=5)
dk = dk.loc[(dk.season==4)]
print(dk.shape)
dk.head(3)
# Out:
# (4232, 17)
#       instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 6250     6251  2011-09-23       4   0     9   0        0        5           1
# 6251     6252  2011-09-23       4   0     9   1        0        5           1
# 6252     6253  2011-09-23       4   0     9   2        0        5           1
#
#       weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 6250           2  0.62  0.5455  0.94     0.0896      11          41   52
# 6251           2  0.60  0.5000  1.00     0.0000       2          29   31
# 6252           2  0.60  0.5000  1.00     0.1045       6          14   20

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Przystosowuje nowe dane z sezonu '4' (zima) do modeli, które zostały wyuczone na danych z sezonu '2' (lato)

# %%
dk2 = dk[['dteday','temp','hum','windspeed','season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit', 'cnt']]

# %%
dk2['windspeed_shift'] = dk2['windspeed']

# %%
dk3 = df_shif(dk2, 'windspeed_shift', lag=13)
dk3.head(7)
## Kasuje dziurę czasową
dk3 = dk3.dropna(how ='any')

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Tworzymy kodowanie na gorąco.

# %%
data_dummy = dk3

def dummify_dataset(df, col):
    dummy_column = pd.get_dummies(df[col], prefix = col, drop_first = True)
    PKP = pd.concat([df,dummy_column],axis = 1)
    PKP = PKP.drop([col], axis=1)
    return PKP


discrete_var = ['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

for i in range(0,8):
    data_dummy = dummify_dataset(data_dummy,discrete_var[i])

# %%
dk4 = data_dummy
dk4.columns
# Out:
# Index(['dteday', 'temp', 'hum', 'windspeed', 'cnt', 'windspeed_shift',
#        'yr_1.0', 'mnth_10.0', 'mnth_11.0', 'mnth_12.0', 'hr_1.0', 'hr_2.0',
#        'hr_3.0', 'hr_4.0', 'hr_5.0', 'hr_6.0', 'hr_7.0', 'hr_8.0', 'hr_9.0',
#        'hr_10.0', 'hr_11.0', 'hr_12.0', 'hr_13.0', 'hr_14.0', 'hr_15.0',
#        'hr_16.0', 'hr_17.0', 'hr_18.0', 'hr_19.0', 'hr_20.0', 'hr_21.0',
#        'hr_22.0', 'hr_23.0', 'holiday_1.0', 'weekday_1.0', 'weekday_2.0',
#        'weekday_3.0', 'weekday_4.0', 'weekday_5.0', 'weekday_6.0',
#        'workingday_1.0', 'weathersit_2.0', 'weathersit_3.0'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Usuwamy zmienną 'dteday'

# %%
dk5= dk4.drop('dteday', axis=1)

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc">Dzielimy zbiór zmienne niezależne i zmieną zależną.

# %%
yp = dk5['cnt']
Xp = dk5.drop('cnt', axis=1)

# %%
dk5['Bagging_Reg'] = Bagging_Reg.predict(Xp)
dk5['ExtraTrees_Reg'] = ExtraTrees_Reg.predict(Xp)
dk5['RandomForest_Reg'] = RandomForest_Reg.predict(Xp)

dk5['dteday'] = dk4['dteday']

dfk5[['RandomForest_Reg','Bagging_Reg','ExtraTrees_Reg','cnt']].head(70).plot(figsize=(24,5),grid=True)

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">  PODSUMOWANIE
#
# <span style="font-size: 110%;color:#1155cc"> Celem było wykonanie modelu, który pomogłby w przewidywaniu pioziomu pobrań rowerów w wypożyczalni miejskiej.
# Modele: 'RandomForest_Reg','Bagging_Reg','ExtraTrees_Reg' lub ich uśrenienie ważone 'KM' potrafią precyzyjnie przewidzieć przyszły poziom wypożyczenia rowerów na podstawie danych pogodowych oraz dni kalendarzowych. Mimo bardzo wysokiego poziomu dopasowania (nieskie 'bias') modele doskonale przewidują poziom wypożyczenia rowerów 'cnt' na zbiorze nieznanym dla modelu (nieska 'wariancja'). Oznacza to, że modele nie są przeuczone.
# Powyższa charakterystyka wskazuje na to, że proces wypożyczania rowerów jest bardzo stabilny.
# Proces zapewne ulegnie w przyszłości destabilizacji (np. COVID19). Wtedy wymagane będzie ponowne przebudowanie modeli.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> Analiza graficzna
#
# <span style="font-size: 110%;color:#1155cc"> Ponieważ jest to zadanie zaliczeniowe powininem również pokazać że potrafie wykonywać prezentacje
# graficzne

# %% [markdown]
# <span style="font-size: 110%;color:#1155cc"> Poziom korelacj ze zmienną zalezną

# %%
def matrix_plot(df,title):

    sns.set(style="ticks")

    corr = df.corr()
    corr = np.round(corr, decimals=2)


    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    f, ax = plt.subplots(figsize=(20, 20))
    #cmap = sns.diverging_palette(580, 10, as_cmap=True)
    cmap = sns.diverging_palette(180, 90, as_cmap=True) #Inna paleta barw

    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=0.3, center=0.03,annot=True,
                square=True, linewidths=.9, cbar_kws={"shrink": 0.8})
    plt.xticks(rotation=90)
    plt.title(title,fontsize=32,color='#0c343d',alpha=0.5)
    plt.show

# %%
matrix_plot(dk,'Pearson correlation')

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Wizualizacja struktury
#
# <span style="font-size: 110%;color:#1155cc"> DANE DYSKRETNE - WYŚWIETLAM ILOŚĆ DANYCH UNIKALNYCH W KAŻDEJ KATEGORII

# %%
dkk = dk[['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']]
categorical_vars=['season','yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 8))
# robie przestrzeń między wykresami 
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.8, hspace=0.3)
# pętla: mamy 9 zmiennych dyskretnych
for i, ax in enumerate(axes.ravel()):
    if i > 8:
        ax.set_visible(False)
        continue
    sns.countplot(y = categorical_vars[i], data=dkk, ax=ax)

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc"> DANE CIĄGŁE

# %%
sns.set(style="white")
_ = dk.hist(column=['windspeed' ,'hum','temp','cnt'], figsize = (8,8))

# %%
def N_plots(df,x1,x2,by,title, x_title):

    plt.figure(dpi= 380)

    fig, axes = joypy.joyplot(df, column=[x1, x2], by=by, ylim='own', figsize=(12,8), legend=True, color=['#f4cccc', '#0c343d'], alpha=0.4)
    # color=['#76a5af', '#134f5c']
    # color=['#f4cccc', '#0c343d']
    # color=['#a4c2f4', '#1c4587']
    #color=['#e06666', '#d9d9d9']
    #color=['#e06666', '#434343']
    #color=['#b6d7a8','#6aa84f']
    
    # Decoration
    plt.title(title, fontsize=22, color='#d0e0e3', alpha=0.9)
    plt.rc("font", size=20)
    plt.xlabel(x_title,  fontsize=16, color='darkred', alpha=1)
    #plt.ylabel('Data Scientist', fontsize=26,  color='grey', alpha=0.8)

    plt.show

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Ilość rowerów zależnie od temperatury i wilgotności w miesiącach

# %%
import joypy
import pandas as pd
import matplotlib.pyplot as plt

df=df
x1='temp'
x2='hum'
by='mnth'
title = 'Ilość rowerów zależnie od temperatury i wilgotności w miesiącach'
x_title = 'Temperatura i wilgotność'

N_plots(df,x1,x2,by,title, x_title)

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Częstotliwość wypożyczania rowerów w roku 2011

# %%
import matplotlib as mpl
import calmap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/home/wojciech/Pulpit/11/hour.csv', parse_dates=['dteday'])
df.set_index('dteday', inplace=True)

# %%
plt.figure(figsize=(16,10), dpi= 280)
calmap.calendarplot(df['2011']['cnt'],cmap= 'YlOrBr', fig_kws={'figsize': (16,10)}, yearlabel_kws={'color':'black', 'fontsize':24}, subplot_kws={'title':'Częstotliwość wypożyczania rowerów w roku 2011'})
plt.show()
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Wypożyczanie rowerów w godzinach zależnie od sezonu

# %%
fig,ax = plt.subplots(figsize = (18,6))
sns.pointplot(data=df[['hr',
                           'cnt',
                           'season']],
              x='hr',
              y='cnt',
              hue='season',
              ax=ax)
ax.set(title="Wypożyczanie rowerów w godzinach zależnie od sezonu")
# Out:
# [Text(0.5, 1.0, 'Wypożyczanie rowerów w godzinach zależnie od sezonu')]

# %%
df.columns
# Out:
# Index(['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Wypożyczanie rowerów zależnie od miesiąca

# %%
fig,ax = plt.subplots(figsize = (18,6))
sns.barplot(data=df[['mnth',
                           'cnt']],
              x='mnth',
              y='cnt',
              ax=ax)
ax.set(title="Miesięczny poziom wypożyczeń")
# Out:
# [Text(0.5, 1.0, 'Miesięczny poziom wypożyczeń')]

# %% [markdown]
# <span style="font-size: 180%;color:#1155cc">Wypożyczanie rowerów zależnie od godzin

# %%
fig,ax = plt.subplots(figsize = (18,6))
sns.boxplot(data=df[['cnt',
                          'hr']],x='hr',y='cnt',ax=ax)
ax.set(title="Checking for outliners in day hours")
# Out:
# [Text(0.5, 1.0, 'Checking for outliners in day hours')]

# %% [markdown]
# ![obraz.png](attachment:obraz.png)
